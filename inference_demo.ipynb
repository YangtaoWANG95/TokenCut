# %%
# !git clone https://github.com/YangtaoWANG95/TokenCut
# %cd TokenCut

# %%
# !pip install torch==1.7.1 torchvision==0.8.2
# !pip install -r requirements.txt

# %%
# !python main_tokencut.py --image_path examples/VOC07_000036.jpg --visualize all
# Out:
# Since no pretrained weights have been provided, we load the reference pretrained DINO weights.
# Pretrained weights found at dino/dino_deitsmall16_pretrain/dino_deitsmall16_pretrain.pth and loaded with msg: <All keys matched successfully>
# Running TokenCut on the dataset VOC07_000036.jpg (exp: TokenCut-vit_small16_k)
#   0% 0/1 [00:00<?, ?it/s]/usr/local/lib/python3.7/dist-packages/torch/nn/functional.py:3063: UserWarning: Default upsampling behavior when mode=bicubic is changed to align_corners=False since 0.4.0. Please specify align_corners=True if the old behavior is desired. See the documentation of nn.Upsample for details.
#   "See the documentation of nn.Upsample for details.".format(mode))
# ...

# %%
from PIL import Image
display(Image.open(r"/content/TokenCut/outputs/TokenCut-vit_small16_k/VOC07_000036_TokenCut_attn.jpg"))
display(Image.open(r"/content/TokenCut/outputs/TokenCut-vit_small16_k/VOC07_000036_TokenCut_pred.jpg"))
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=336x512 at 0x7FD8A1AA4610>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=332x500 at 0x7FD8A1AA92D0>
